# %% [markdown]
# ### What is Data Aggregation?
# > Aggregation is the process of combining data from multiple sources into a single summary.
# >  It is the process of
# > summarizing,
# > grouping, and
# > condensing data.
#
# > The goal of data aggregation is to "gain insights from large datasets" and to make the data more "manageable"

# %% [markdown]
# #  Using the Groupby fun:
# > Grouping is the process of dividing a dataset into smaller subsets based on one or more variables.
# > It is a common method used to explore and analyze data.
#
#
# > groupby() -->  to group data by one or more columns / variables. --> then aggregation func

# %%
#  Aggregating Data by Single Column using groupby()
import pandas as pd
df = pd.read_csv('HousingDataset.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Aggregating Data by Single Column
df_agg = df.groupby('YrSold')['SalePrice'].mean()
print(df_agg)
# Out:
# YrSold
# 2006    182549.458599
# 2007    186063.151976
# 2008    177360.838816
# 2009    179432.103550
# 2010    177393.674286
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Aggregating Data by Multiple Columns
# > passing a list of column names to the groupby()
# >
# > This will group the data by both YrSold and Street and then calculate the sum of the SalePrice for each combination of YrSold and Street.

# %%
df_agg = df.groupby(['YrSold','Street','SaleCondition'])['SalePrice'].mean()
print(df_agg)
# Out:
# YrSold  Street  SaleCondition
# 2006    Pave    Abnorml          142857.363636
#                 AdjLand          104250.000000
#                 Alloca           274970.000000
#                 Family           138500.000000
#                 Normal           175522.612335
#                 Partial          259793.813953
# 2007    Grvl    Normal           152600.000000
#         Pave    Abnorml          198346.153846
#                 AdjLand          126000.000000
#                 Alloca           216398.333333
#                 Family           176142.857143
#                 Normal           175484.840304
#                 Partial          254259.225000
# 2008    Grvl    Normal           154975.000000
#         Pave    Abnorml          154500.000000
#                 AdjLand           82000.000000
#                 Alloca           157629.500000
#                 Normal           172192.996183
#                 Partial          303213.812500
# ...

# %%
# Applying Multiple Functions to Grouped Data
# This will group the data by ‘YrSold’, ’SaleType’ and then calculate the ‘min’, ‘max’, ‘mean’, ‘sum’ SaleType for each ‘YrSold’ and ‘SaleType'.
df_agg = df.groupby(['YrSold','SaleType'])['SalePrice'].agg(['min','max','mean','sum'])
print(df_agg)
# Out:
#                     min     max           mean       sum
# YrSold SaleType
# 2006   COD       102000  140000  119700.000000    598500
#        ConLD     140000  160000  150000.000000    300000
#        ConLI     125000  125000  125000.000000    125000
#        ConLw     144000  144000  144000.000000    144000
#        New       140000  556581  259793.813953  11171134
#        Oth       116050  116050  116050.000000    116050
#        WD         35311  625000  171899.793103  44865846
# 2007   COD       114500  217000  153880.000000    769400
#        CWD       136000  219500  171166.666667    513500
#        New       147000  440000  254259.225000  10170369
#        Oth        93500  150000  121750.000000    243500
#        WD         39300  755000  177483.899642  49518008
# 2008   COD        85400  287000  149796.428571   2097150
#        CWD       328900  328900  328900.000000    328900
#        Con       324000  324000  324000.000000    324000
# ...

# %% [markdown]
# # Pivot Tables:
# > summarize and manipulate data in a tabular format
# > Pivot tables --> perform complex data analysis tasks, such as
# > data aggregation, filtering, and sorting.
# Purpose:
# >DataFrame as input --> groups the data one /  more columns -->applies a set of aggregate functions to the data, and produces output as  a new table of summary statistics.

# %%
#Aggregating Data by Single Column
# creating pivot table of total Sale Price
# Year Sold-wise agg func = 'mean' will allow you to obtain the average of SalePrice for each YrSold
pivot = df.pivot_table(index =['YrSold'],    # Categorical variable
                       values =['SalePrice'],
                       aggfunc =['mean'])
print(pivot)
# Out:
#                  mean
#             SalePrice
# YrSold
# 2006    182549.458599
# 2007    186063.151976
# 2008    177360.838816
# 2009    179432.103550
# 2010    177393.674286

# %%
# Aggregating Data by Multiple Columns
# creating pivot table of total Sale Price
# Year Sold-wise aggfunc = 'sum' will allow you to obtain the sumof SalePrice for each YrSold and SaleType
pivot = df.pivot_table(index =['YrSold', 'SaleType'], # Categorical variable
                       values =['SalePrice'],
                       aggfunc =['sum'])
print(pivot)
# Out:
#                       sum
#                 SalePrice
# YrSold SaleType
# 2006   COD         598500
#        ConLD       300000
#        ConLI       125000
#        ConLw       144000
#        New       11171134
#        Oth         116050
#        WD        44865846
# 2007   COD         769400
#        CWD         513500
#        New       10170369
#        Oth         243500
#        WD        49518008
# 2008   COD        2097150
#        CWD         328900
#        Con         324000
#        ConLD       665528
#        ConLw        95000
#        New        4501293
#        WD        45905824
# 2009   COD        1998000
#        ConLD       283500
#        ConLI       761950
#        ConLw       479500
#        New        5363764
#        WD        51761337
# 2010   COD         727800
#        Con         215200
#        ConLI       115000
#        New        2336781
#        WD        27649112

# %%
# Applying Multiple Functions to Grouped Data
# creating pivot table of total Sale Price
# Year Sold-wise aggfunc = ['min','max','mean', 'sum'] will allow you to obtain the min, max, mean, sum of SalePrice for each YrSold, SaleType
pivot = df.pivot_table(index =['YrSold','SaleType'], # Categorical variable
                       values =['SalePrice'],
                       aggfunc =['min','max','mean', 'sum'])
print(pivot)
# Out:
#                       min       max           mean       sum
#                 SalePrice SalePrice      SalePrice SalePrice
# YrSold SaleType
# 2006   COD         102000    140000  119700.000000    598500
#        ConLD       140000    160000  150000.000000    300000
#        ConLI       125000    125000  125000.000000    125000
#        ConLw       144000    144000  144000.000000    144000
#        New         140000    556581  259793.813953  11171134
#        Oth         116050    116050  116050.000000    116050
#        WD           35311    625000  171899.793103  44865846
# 2007   COD         114500    217000  153880.000000    769400
#        CWD         136000    219500  171166.666667    513500
#        New         147000    440000  254259.225000  10170369
#        Oth          93500    150000  121750.000000    243500
#        WD           39300    755000  177483.899642  49518008
# 2008   COD          85400    287000  149796.428571   2097150
# ...

# %% [markdown]
# ### Reshaping Data
# > Reshaping is the process of converting data from one shape to another.
# > Pandas provides many functions for reshaping data, including
# > melt(), stack(), and unstack().

# %%
df[['1stFlrSF', '2ndFlrSF']]
# Out:
#       1stFlrSF  2ndFlrSF
# 0          856       854
# 1         1262         0
# 2          920       866
# 3          961       756
# 4         1145      1053
# ...        ...       ...
# 1455       953       694
# 1456      2073         0
# 1457      1188      1152
# 1458      1078         0
# 1459      1256         0
#
# [1460 rows x 2 columns]

# %%
df[['1stFlrSF', '2ndFlrSF', 'YrSold']]
# Out:
#       1stFlrSF  2ndFlrSF  YrSold
# 0          856       854    2008
# 1         1262         0    2007
# 2          920       866    2008
# 3          961       756    2006
# 4         1145      1053    2008
# ...        ...       ...     ...
# 1455       953       694    2007
# 1456      2073         0    2010
# 1457      1188      1152    2010
# 1458      1078         0    2010
# 1459      1256         0    2008
#
# [1460 rows x 3 columns]

# %% [markdown]
# melt():
# > reshape the DataFrame --> one / more columns are “melted” into a single column,
# the original columns being stored in a new “value” column
# >
# > The function can be used to unpivot a DataFrame and reshape it into a format

# %%
# reshape data using melt function
df_melted = pd.melt(df, id_vars=['YrSold'], value_vars=['1stFlrSF', '2ndFlrSF'],
                    var_name='FlrSF', value_name='SF')
# print melted data
print(df_melted)
# Out:
#       YrSold     FlrSF    SF
# 0       2008  1stFlrSF   856
# 1       2007  1stFlrSF  1262
# 2       2008  1stFlrSF   920
# 3       2006  1stFlrSF   961
# 4       2008  1stFlrSF  1145
# ...      ...       ...   ...
# 2915    2007  2ndFlrSF   694
# 2916    2010  2ndFlrSF     0
# 2917    2010  2ndFlrSF  1152
# 2918    2010  2ndFlrSF     0
# 2919    2008  2ndFlrSF     0
#
# [2920 rows x 3 columns]

# %% [markdown]
#  stack():

# %%
# create a sample dataframe
data = {'Name': ['John', 'Jane', 'Peter', 'Mary'],
        'Maths': [90, 80, 70, 60],
        'Science': [85, 75, 65, 55],
        'English': [80, 95, 85, 75]}
df1 = pd.DataFrame(data)
print(df1)
# Out:
#     Name  Maths  Science  English
# 0   John     90       85       80
# 1   Jane     80       75       95
# 2  Peter     70       65       85
# 3   Mary     60       55       75

# %%
# stack the dataframe
stacked = df1.set_index('Name').stack().reset_index()
stacked.columns = ['Name', 'Subject', 'Score']
stacked.columns
# Out:
# Index(['Name', 'Subject', 'Score'], dtype='object')

# %%
# group the data by subject and calculate the mean score
grouped = stacked.groupby('Subject')['Score'].mean().reset_index()

print("\nRaw Data")
print(df1)
print("\nStack Data")
print(grouped)
# Out:
# Raw Data
#     Name  Maths  Science  English
# 0   John     90       85       80
# 1   Jane     80       75       95
# 2  Peter     70       65       85
# 3   Mary     60       55       75
#
# Stack Data
#    Subject  Score
# 0  English  83.75
# 1    Maths  75.00
# 2  Science  70.00

# %% [markdown]
# ### unstack:
# > convert a stacked DataFrame into a pivoted DataFrame
# > uses level parameter --> specifies which level of the index to unstack.

# %%
# Unstack
# Creating a sample data frame
data = {'year': [2010, 2011, 2012],
        'USA': [100, 200, 300],
        'Canada': [150, 250, 350]}

df1 = pd.DataFrame(data)
print(df1)
# Out:
#    year  USA  Canada
# 0  2010  100     150
# 1  2011  200     250
# 2  2012  300     350

# %%
df_unstack = df1.unstack()
print(df_unstack)
# Out:
# year    0    2010
#         1    2011
#         2    2012
# USA     0     100
#         1     200
#         2     300
# Canada  0     150
#         1     250
#         2     350
# dtype: int64

# %%
print(df1.unstack(0))
# Out:
# year    0    2010
#         1    2011
#         2    2012
# USA     0     100
#         1     200
#         2     300
# Canada  0     150
#         1     250
#         2     350
# dtype: int64

# %%
# Reshaping the data using unstack function
df_unstack = df1.set_index('year').unstack().reset_index(name='sales').rename(columns={'level_0': 'country'})
print("*"*40)
print("Raw Data")
print("*"*40)
print(df1)
print("*"*40)
print("Unstack Data")
print("*"*40)
print(df_unstack)
# Out:
# ****************************************
# Raw Data
# ****************************************
#    year  USA  Canada
# 0  2010  100     150
# 1  2011  200     250
# 2  2012  300     350
# ****************************************
# Unstack Data
# ****************************************
#   country  year  sales
# 0     USA  2010    100
# 1     USA  2011    200
# 2     USA  2012    300
# 3  Canada  2010    150
# 4  Canada  2011    250
# 5  Canada  2012    350

# %%
df_FlrSF = df.loc[:,['YrSold','1stFlrSF','1stFlrSF']]

# Reshaping the data using unstack function
df_unstack = df_FlrSF.set_index('YrSold').unstack().reset_index(name='FlrSF').rename(columns={'level_0': 'SF'})

print(df_unstack)
# Out:
#             SF  YrSold  FlrSF
# 0     1stFlrSF    2008    856
# 1     1stFlrSF    2007   1262
# 2     1stFlrSF    2008    920
# 3     1stFlrSF    2006    961
# 4     1stFlrSF    2008   1145
# ...        ...     ...    ...
# 2915  1stFlrSF    2007    953
# 2916  1stFlrSF    2010   2073
# 2917  1stFlrSF    2010   1188
# 2918  1stFlrSF    2010   1078
# 2919  1stFlrSF    2008   1256
#
# [2920 rows x 3 columns]
